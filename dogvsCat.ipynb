# %% [markdown]
# <a href="https://colab.research.google.com/github/Manideep317/Assignment-3-IOT/blob/main/dogvsCat.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
from tensorflow.keras.applications.resnet50 import ResNet50,preprocess_input, decode_predictions

# %%
import numpy as np

# %%
import cv2

# %%
model = ResNet50(weights='imagenet')

# %%
import matplotlib.pyplot as plt

# %%
def classify(image):
  image = preprocess_input(image)
  preds = model.predict(np.array([image]))
  results = decode_predictions(preds, top=1)[0]
  decode_predictions(preds, top=1)
  return results

# %%
image = cv2.imread('/content/cat1.jpg')
image = cv2.resize(image, (224,224))
plt.imshow(image)

# %%
results=classify(image)
for result in results:
  print(result[1], ':',result[2])
# Out:
# 1/1 [==============================] - 1s 913ms/step
# Egyptian_cat : 0.6546121

# %%
img = cv2.imread('/content/cat2.jpg')
img = cv2.resize(img, (224,224))
plt.imshow(img)

# %%
results=classify(img)
for result in results:
  print(result[1], ':',result[2])
# Out:
# 1/1 [==============================] - 0s 25ms/step
# Egyptian_cat : 0.95134306

# %%
img = cv2.imread('/content/dog1.jpeg')
img = cv2.resize(img, (224,224))
plt.imshow(img)

# %%
results=classify(image)
for output in results:
  print(output[1], ':',output[2])
# Out:
# 1/1 [==============================] - 0s 23ms/step
# Egyptian_cat : 0.6546121

# %%
image = cv2.imread('/content/dog2.jpeg')
image = cv2.resize(image, (224,224))
plt.imshow(image)

# %%
results=classify(image)
for output in results:
  print(output[1], ':',output[2])
# Out:
# 1/1 [==============================] - 0s 25ms/step
# Great_Pyrenees : 0.6653056
